# %%
# load library
library(ActiveDriver)

# %%
# load required datasets
muts = read.delim("pancan12_example/mutations.txt")
sites = read.delim("pancan12_example/phosphosites.txt")
seqs = read_fasta("pancan12_example/sequences.fa")
disorder = read_fasta("pancan12_example/sequence_disorder.fa")

# %%
# run ActiveDriver
psnv_info = ActiveDriver(seqs, disorder, muts, sites)
# Out:
# genes: 7
# Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”
# .
# Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”
# ..
# Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”
# .
# Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”
# .
# Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”
# .
# Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”Warning message:
# “glm.fit: fitted rates numerically 0 occurred”
# .

# %%
# save gene-based p-values and merged report as CSV files
write.csv(psnv_info$all_gene_based_fdr, "pancan12_results_pvals.csv")
write.csv(psnv_info$merged_report, "pancan12_results_merged.csv")

# %%
# look at first few lines of every table in results
lapply(psnv_info, head)
# Out:
# $all_active_mutations
#   gene cancer_type                    sample_id position wt_residue mut_residue
# 1 ABL1   pancancer TCGA-BT-A2LA-01A-11D-A18F-08      265          H           Y
# 2 ABL1   pancancer TCGA-GD-A3OS-01A-12D-A21Z-08       91          F           V
# 3 ABL1   pancancer TCGA-A8-A094-01A-11W-A019-09      459          Y           H
# 4 ABL1   pancancer TCGA-E2-A1LB-01A-11D-A142-09       90          D           N
# 5 ABL1   pancancer TCGA-B0-5696-01A-11D-1534-10       94          S           R
# 6 ABL1   pancancer TCGA-BP-4159-01A-02D-1366-10      185          R           K
#   count status active_region
# 1     1     N2             7
# 2     1  N1,N2             3
# 3     1     N2            11
# 4     1  N1,N2             3
# 5     1  DI,N2             3
# 6     1  N1,N2             5
#
# $all_active_sites
#   gene position residue      kinase                               pmid
# 1 ABL1       16       S                                   PUBMED_MS2.1
# 2 ABL1       62       S                      PUBMED_MS2.1,PUBMED_MS2.2
# 3 ABL1       69       S             18691976,PUBMED_MS2.1,PUBMED_MS2.2
# 4 ABL1       89       Y FYN,HCK,LYN          PUBMED_LTP.1,PUBMED_LTP.2
# 5 ABL1       94       S FYN,HCK,LYN          PUBMED_LTP.1,PUBMED_LTP.2
# 6 ABL1       98       T                                       20068231
#   active_region
# 1             1
# 2             2
# 3             2
# 4             3
# 5             3
# 6             3
#
# $all_region_based_pval
#   gene region            p         low   med      high obs
# 1 ABL1      1           NA -0.23861030 0.157 0.5526103   0
# 2 ABL1      2           NA -0.24342151 0.228 0.6994215   1
# 3 ABL1      3 0.0003382389  0.03591393 1.064 2.0920861   5
# 4 ABL1      4 0.1024598982  0.13317634 1.282 2.4308237   0
# 5 ABL1      5 0.0237944097 -0.01973272 1.025 2.0697327   2
# 6 ABL1      6           NA -0.12545771 0.626 1.3774577   0
#
# $all_gene_based_fdr
#          gene            p          fdr
# ABL1     ABL1 9.941860e-09 1.159884e-08
# CTCF     CTCF 1.006234e-12 1.408728e-12
# CTNNB1 CTNNB1 3.768245e-78 2.637771e-77
# EGFR     EGFR 1.669824e-30 2.922192e-30
# IDH1     IDH1 1.811817e-73 4.227573e-73
# PTEN     PTEN 8.043822e-04 8.043822e-04
#
# $all_active_regions
#   gene reg pos0 pos1 Freq
# 1 ABL1   1    A Min.    9
# 2 ABL1   1    A Max.   23
# 3 ABL1   2    A Min.   55
# 4 ABL1   2    A Max.   76
# 5 ABL1   3    A Min.   82
# 6 ABL1   3    A Max.  119
#
# $merged_report
#                      sample_id mut_position wt_residue mut_residue count status
# 1 TCGA-A8-A094-01A-11W-A019-09          459          Y           H     1     N2
# 2 TCGA-A8-A094-01A-11W-A019-09          459          Y           H     1     N2
# 3 TCGA-66-2786-01A-01D-1522-08          472          E           Q     1     N2
# 4 TCGA-66-2786-01A-01D-1522-08          472          E           Q     1     N2
# 5 TCGA-A5-A0VO-01A-21D-A10G-09           75          A           T     1     N2
# 6 TCGA-A5-A0VO-01A-21D-A10G-09           75          A           T     1     N2
#   active_region Freq gene PTM_position residue kinase
# 1            11  472 ABL1          465       S    ATM
# 2            11  458 ABL1          465       S    ATM
# 3            11  472 ABL1          465       S    ATM
# 4            11  458 ABL1          465       S    ATM
# 5             2   76 ABL1           69       S
# 6             2   55 ABL1           69       S
#                                 pmid active_region_p
# 1       8668151,9168116,PUBMED_LTP.1       0.0383889
# 2       8668151,9168116,PUBMED_LTP.1       0.0383889
# 3       8668151,9168116,PUBMED_LTP.1       0.0383889
# 4       8668151,9168116,PUBMED_LTP.1       0.0383889
# 5 18691976,PUBMED_MS2.1,PUBMED_MS2.2              NA
# 6 18691976,PUBMED_MS2.1,PUBMED_MS2.2              NA

# %%
psnv_info$merged_report
# Out:
#      sample_id                    mut_position wt_residue mut_residue count
# 1    TCGA-A8-A094-01A-11W-A019-09 459          Y          H           1
# 2    TCGA-A8-A094-01A-11W-A019-09 459          Y          H           1
# 3    TCGA-66-2786-01A-01D-1522-08 472          E          Q           1
# 4    TCGA-66-2786-01A-01D-1522-08 472          E          Q           1
# 5    TCGA-A5-A0VO-01A-21D-A10G-09  75          A          T           1
# 6    TCGA-A5-A0VO-01A-21D-A10G-09  75          A          T           1
# 7    TCGA-AB-2999-03A-01D-0739-09 937          P          L           1
# 8    TCGA-AB-2999-03A-01D-0739-09 937          P          L           1
# 9    TCGA-AB-2999-03A-01D-0739-09 937          P          L           1
# 10   TCGA-AB-2999-03A-01D-0739-09 937          P          L           1
# 11   TCGA-AB-2999-03A-01D-0739-09 937          P          L           1
# 12   TCGA-AB-2999-03A-01D-0739-09 937          P          L           1
# 13   TCGA-GD-A3OS-01A-12D-A21Z-08  91          F          V           1
# 14   TCGA-GD-A3OS-01A-12D-A21Z-08  91          F          V           1
# 15   TCGA-GD-A3OS-01A-12D-A21Z-08  91          F          V           1
# 16   TCGA-GD-A3OS-01A-12D-A21Z-08  91          F          V           1
# 17   TCGA-GD-A3OS-01A-12D-A21Z-08  91          F          V           1
# 18   TCGA-GD-A3OS-01A-12D-A21Z-08  91          F          V           1
# 19   TCGA-E2-A1LB-01A-11D-A142-09  90          D          N           1
# 20   TCGA-E2-A1LB-01A-11D-A142-09  90          D          N           1
# 21   TCGA-E2-A1LB-01A-11D-A142-09  90          D          N           1
# 22   TCGA-E2-A1LB-01A-11D-A142-09  90          D          N           1
# 23   TCGA-B0-5696-01A-11D-1534-10  94          S          R           1
# 24   TCGA-B0-5696-01A-11D-1534-10  94          S          R           1
# 25   TCGA-B0-5696-01A-11D-1534-10  94          S          R           1
# 26   TCGA-B0-5696-01A-11D-1534-10  94          S          R           1
# 27   TCGA-B0-5696-01A-11D-1534-10  94          S          R           1
# 28   TCGA-B0-5696-01A-11D-1534-10  94          S          R           1
# 29   TCGA-A5-A0GP-01A-11W-A062-09  91          F          V           1
# 30   TCGA-A5-A0GP-01A-11W-A062-09  91          F          V           1
# ⋮    ⋮                            ⋮            ⋮          ⋮           ⋮
# 2315 TCGA-18-3415-01A-01D-0983-08 282          R          Q           1
# 2316 TCGA-18-3415-01A-01D-0983-08 282          R          Q           1
# 2317 TCGA-61-2113-01A-01W-0722-08 266          G          V           1
# 2318 TCGA-61-2113-01A-01W-0722-08 266          G          V           1
# 2319 TCGA-33-4582-01A-01D-1441-08 278          P          S           1
# 2320 TCGA-33-4582-01A-01D-1441-08 278          P          S           1
# 2321 TCGA-CQ-5330-01A-01D-1683-08 266          G          R           1
# 2322 TCGA-CQ-5330-01A-01D-1683-08 266          G          R           1
# 2323 TCGA-BG-A0M6-01A-31D-A10B-09 272          V          M           1
# 2324 TCGA-BG-A0M6-01A-31D-A10B-09 272          V          M           1
# 2325 TCGA-AA-3667-01A-01W-0900-09 282          R          W           1
# 2326 TCGA-AA-3667-01A-01W-0900-09 282          R          W           1
# 2327 TCGA-25-1321-01A-01W-0492-08 273          R          C           1
# 2328 TCGA-25-1321-01A-01W-0492-08 273          R          C           1
# 2329 TCGA-24-1426-01A-01W-0549-09 273          R          C           1
# 2330 TCGA-24-1426-01A-01W-0549-09 273          R          C           1
# 2331 TCGA-24-1463-01A-01W-0549-09 274          V          D           1
# 2332 TCGA-24-1463-01A-01W-0549-09 274          V          D           1
# 2333 TCGA-59-2352-01A-01W-0799-08 266          G          V           1
# 2334 TCGA-59-2352-01A-01W-0799-08 266          G          V           1
# 2335 TCGA-A5-A0G3-01A-11W-A062-09 273          R          C           1
# 2336 TCGA-A5-A0G3-01A-11W-A062-09 273          R          C           1
# 2337 TCGA-76-6286-01A-11D-1845-08 375          Q          K           1
# 2338 TCGA-76-6286-01A-11D-1845-08 375          Q          K           1
# 2339 TCGA-76-6286-01A-11D-1845-08 375          Q          K           1
# 2340 TCGA-76-6286-01A-11D-1845-08 375          Q          K           1
# 2341 TCGA-76-6286-01A-11D-1845-08 375          Q          K           1
# 2342 TCGA-76-6286-01A-11D-1845-08 375          Q          K           1
# 2343 TCGA-76-6286-01A-11D-1845-08 375          Q          K           1
# 2344 TCGA-76-6286-01A-11D-1845-08 375          Q          K           1
#      status active_region Freq gene PTM_position residue
# 1    N2     11            472  ABL1 465          S
# 2    N2     11            458  ABL1 465          S
# 3    N2     11            472  ABL1 465          S
# 4    N2     11            458  ABL1 465          S
# 5    N2      2             76  ABL1  69          S
# 6    N2      2             55  ABL1  69          S
# 7    N1,N2  22            927  ABL1 938          S
# 8    N1,N2  22            927  ABL1 934          S
# 9    N1,N2  22            927  ABL1 936          S
# 10   N1,N2  22            945  ABL1 938          S
# 11   N1,N2  22            945  ABL1 934          S
# 12   N1,N2  22            945  ABL1 936          S
# 13   N1,N2   3             82  ABL1  98          T
# 14   N1,N2   3             82  ABL1  89          Y
# 15   N1,N2   3             82  ABL1  94          S
# 16   N1,N2   3            119  ABL1  98          T
# 17   N1,N2   3            119  ABL1  89          Y
# 18   N1,N2   3            119  ABL1  94          S
# 19   N1,N2   3             82  ABL1  89          Y
# 20   N1,N2   3             82  ABL1  94          S
# 21   N1,N2   3            119  ABL1  89          Y
# 22   N1,N2   3            119  ABL1  94          S
# 23   DI,N2   3             82  ABL1  98          T
# 24   DI,N2   3             82  ABL1  89          Y
# 25   DI,N2   3             82  ABL1  94          S
# 26   DI,N2   3            119  ABL1  98          T
# 27   DI,N2   3            119  ABL1  89          Y
# 28   DI,N2   3            119  ABL1  94          S
# 29   N1,N2   3             82  ABL1  98          T
# 30   N1,N2   3             82  ABL1  89          Y
# ⋮    ⋮      ⋮             ⋮    ⋮    ⋮            ⋮
# 2315 N1     7             291  TP53 284          T
# 2316 N1     7             262  TP53 284          T
# 2317 N2     7             291  TP53 269          S
# 2318 N2     7             262  TP53 269          S
# 2319 N2     7             291  TP53 284          T
# 2320 N2     7             262  TP53 284          T
# 2321 N2     7             291  TP53 269          S
# 2322 N2     7             262  TP53 269          S
# 2323 N2     7             291  TP53 269          S
# 2324 N2     7             262  TP53 269          S
# 2325 N1     7             291  TP53 284          T
# 2326 N1     7             262  TP53 284          T
# 2327 N2     7             291  TP53 269          S
# 2328 N2     7             262  TP53 269          S
# 2329 N2     7             291  TP53 269          S
# 2330 N2     7             262  TP53 269          S
# 2331 N2     7             291  TP53 269          S
# 2332 N2     7             262  TP53 269          S
# 2333 N2     7             291  TP53 269          S
# 2334 N2     7             262  TP53 269          S
# 2335 N2     7             291  TP53 269          S
# 2336 N2     7             262  TP53 269          S
# 2337 N1,N2  9             355  TP53 371          S
# 2338 N1,N2  9             355  TP53 376          S
# 2339 N1,N2  9             355  TP53 377          T
# 2340 N1,N2  9             355  TP53 378          S
# 2341 N1,N2  9             393  TP53 371          S
# 2342 N1,N2  9             393  TP53 376          S
# 2343 N1,N2  9             393  TP53 377          T
# 2344 N1,N2  9             393  TP53 378          S
#      kinase
# 1    ATM
# 2    ATM
# 3    ATM
# 4    ATM
# 5
# 6
# 7    ABL1
# 8
# 9
# 10   ABL1
# 11
# 12
# 13
# 14   FYN,HCK,LYN
# 15   FYN,HCK,LYN
# 16
# 17   FYN,HCK,LYN
# 18   FYN,HCK,LYN
# 19   FYN,HCK,LYN
# 20   FYN,HCK,LYN
# 21   FYN,HCK,LYN
# 22   FYN,HCK,LYN
# 23
# 24   FYN,HCK,LYN
# 25   FYN,HCK,LYN
# 26
# 27   FYN,HCK,LYN
# 28   FYN,HCK,LYN
# 29
# 30   FYN,HCK,LYN
# ⋮    ⋮
# 2315 AURKB
# 2316 AURKB
# 2317 AURKB,DAPK1
# 2318 AURKB,DAPK1
# 2319 AURKB
# 2320 AURKB
# 2321 AURKB,DAPK1
# 2322 AURKB,DAPK1
# 2323 AURKB,DAPK1
# 2324 AURKB,DAPK1
# 2325 AURKB
# 2326 AURKB
# 2327 AURKB,DAPK1
# 2328 AURKB,DAPK1
# 2329 AURKB,DAPK1
# 2330 AURKB,DAPK1
# 2331 AURKB,DAPK1
# 2332 AURKB,DAPK1
# 2333 AURKB,DAPK1
# 2334 AURKB,DAPK1
# 2335 AURKB,DAPK1
# 2336 AURKB,DAPK1
# 2337 CDK7,CHEK1,CHEK2,GSK3B,PRKACA,PRKCA
# 2338 CDK7,CHEK1,CHEK2,GSK3B,PRKACA,PRKCA
# 2339 CDK7,CHEK1,CHEK2,GSK3B,PRKACA,PRKCA
# 2340 CDK7,CHEK1,CHEK2,GSK3B,PRKACA,PRKCA
# 2341 CDK7,CHEK1,CHEK2,GSK3B,PRKACA,PRKCA
# 2342 CDK7,CHEK1,CHEK2,GSK3B,PRKACA,PRKCA
# 2343 CDK7,CHEK1,CHEK2,GSK3B,PRKACA,PRKCA
# 2344 CDK7,CHEK1,CHEK2,GSK3B,PRKACA,PRKCA
#      pmid
# 1    8668151,9168116,PUBMED_LTP.1
# 2    8668151,9168116,PUBMED_LTP.1
# 3    8668151,9168116,PUBMED_LTP.1
# 4    8668151,9168116,PUBMED_LTP.1
# 5    18691976,PUBMED_MS2.1,PUBMED_MS2.2
# 6    18691976,PUBMED_MS2.1,PUBMED_MS2.2
# 7    17192257,18691976,PUBMED_MS2.1,PUBMED_MS2.2
# 8    18452278,18691976
# 9    18452278,18669648,18691976,19651622,PUBMED_MS2.1,PUBMED_MS2.2
# 10   17192257,18691976,PUBMED_MS2.1,PUBMED_MS2.2
# 11   18452278,18691976
# 12   18452278,18669648,18691976,19651622,PUBMED_MS2.1,PUBMED_MS2.2
# 13   20068231
# 14   PUBMED_LTP.1,PUBMED_LTP.2
# 15   PUBMED_LTP.1,PUBMED_LTP.2
# 16   20068231
# 17   PUBMED_LTP.1,PUBMED_LTP.2
# 18   PUBMED_LTP.1,PUBMED_LTP.2
# 19   PUBMED_LTP.1,PUBMED_LTP.2
# 20   PUBMED_LTP.1,PUBMED_LTP.2
# 21   PUBMED_LTP.1,PUBMED_LTP.2
# 22   PUBMED_LTP.1,PUBMED_LTP.2
# 23   20068231
# 24   PUBMED_LTP.1,PUBMED_LTP.2
# 25   PUBMED_LTP.1,PUBMED_LTP.2
# 26   20068231
# 27   PUBMED_LTP.1,PUBMED_LTP.2
# 28   PUBMED_LTP.1,PUBMED_LTP.2
# 29   20068231
# 30   PUBMED_LTP.1,PUBMED_LTP.2
# ⋮    ⋮
# 2315 PUBMED_LTP.1,PUBMED_MS2.1
# 2316 PUBMED_LTP.1,PUBMED_MS2.1
# 2317 PUBMED_LTP.1,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_MS2.1
# 2318 PUBMED_LTP.1,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_MS2.1
# 2319 PUBMED_LTP.1,PUBMED_MS2.1
# 2320 PUBMED_LTP.1,PUBMED_MS2.1
# 2321 PUBMED_LTP.1,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_MS2.1
# 2322 PUBMED_LTP.1,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_MS2.1
# 2323 PUBMED_LTP.1,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_MS2.1
# 2324 PUBMED_LTP.1,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_MS2.1
# 2325 PUBMED_LTP.1,PUBMED_MS2.1
# 2326 PUBMED_LTP.1,PUBMED_MS2.1
# 2327 PUBMED_LTP.1,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_MS2.1
# 2328 PUBMED_LTP.1,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_MS2.1
# 2329 PUBMED_LTP.1,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_MS2.1
# 2330 PUBMED_LTP.1,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_MS2.1
# 2331 PUBMED_LTP.1,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_MS2.1
# 2332 PUBMED_LTP.1,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_MS2.1
# 2333 PUBMED_LTP.1,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_MS2.1
# 2334 PUBMED_LTP.1,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_MS2.1
# 2335 PUBMED_LTP.1,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_MS2.1
# 2336 PUBMED_LTP.1,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_MS2.1
# 2337 9315650,9571186,PUBMED_LTP.1,PUBMED_LTP.10,PUBMED_LTP.11,PUBMED_LTP.12,PUBMED_LTP.13,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_LTP.4,PUBMED_LTP.5,PUBMED_LTP.6,PUBMED_LTP.7,PUBMED_LTP.8,PUBMED_LTP.9,PUBMED_MS2.1
# 2338 9315650,PUBMED_LTP.1,PUBMED_LTP.10,PUBMED_LTP.11,PUBMED_LTP.12,PUBMED_LTP.13,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_LTP.4,PUBMED_LTP.5,PUBMED_LTP.6,PUBMED_LTP.7,PUBMED_LTP.8,PUBMED_LTP.9,PUBMED_MS2.1
# 2339 PUBMED_LTP.1,PUBMED_LTP.10,PUBMED_LTP.11,PUBMED_LTP.12,PUBMED_LTP.13,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_LTP.4,PUBMED_LTP.5,PUBMED_LTP.6,PUBMED_LTP.7,PUBMED_LTP.8,PUBMED_LTP.9,PUBMED_MS2.1
# 2340 1454855,9315650,PUBMED_LTP.1,PUBMED_LTP.10,PUBMED_LTP.11,PUBMED_LTP.12,PUBMED_LTP.13,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_LTP.4,PUBMED_LTP.5,PUBMED_LTP.6,PUBMED_LTP.7,PUBMED_LTP.8,PUBMED_LTP.9,PUBMED_MS2.1
# 2341 9315650,9571186,PUBMED_LTP.1,PUBMED_LTP.10,PUBMED_LTP.11,PUBMED_LTP.12,PUBMED_LTP.13,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_LTP.4,PUBMED_LTP.5,PUBMED_LTP.6,PUBMED_LTP.7,PUBMED_LTP.8,PUBMED_LTP.9,PUBMED_MS2.1
# 2342 9315650,PUBMED_LTP.1,PUBMED_LTP.10,PUBMED_LTP.11,PUBMED_LTP.12,PUBMED_LTP.13,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_LTP.4,PUBMED_LTP.5,PUBMED_LTP.6,PUBMED_LTP.7,PUBMED_LTP.8,PUBMED_LTP.9,PUBMED_MS2.1
# 2343 PUBMED_LTP.1,PUBMED_LTP.10,PUBMED_LTP.11,PUBMED_LTP.12,PUBMED_LTP.13,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_LTP.4,PUBMED_LTP.5,PUBMED_LTP.6,PUBMED_LTP.7,PUBMED_LTP.8,PUBMED_LTP.9,PUBMED_MS2.1
# 2344 1454855,9315650,PUBMED_LTP.1,PUBMED_LTP.10,PUBMED_LTP.11,PUBMED_LTP.12,PUBMED_LTP.13,PUBMED_LTP.2,PUBMED_LTP.3,PUBMED_LTP.4,PUBMED_LTP.5,PUBMED_LTP.6,PUBMED_LTP.7,PUBMED_LTP.8,PUBMED_LTP.9,PUBMED_MS2.1
#      active_region_p
# 1    0.0383888963
# 2    0.0383888963
# 3    0.0383888963
# 4    0.0383888963
# 5              NA
# 6              NA
# 7    0.0321783329
# 8    0.0321783329
# 9    0.0321783329
# 10   0.0321783329
# 11   0.0321783329
# 12   0.0321783329
# 13   0.0003382389
# 14   0.0003382389
# 15   0.0003382389
# 16   0.0003382389
# 17   0.0003382389
# 18   0.0003382389
# 19   0.0003382389
# 20   0.0003382389
# 21   0.0003382389
# 22   0.0003382389
# 23   0.0003382389
# 24   0.0003382389
# 25   0.0003382389
# 26   0.0003382389
# 27   0.0003382389
# 28   0.0003382389
# 29   0.0003382389
# 30   0.0003382389
# ⋮    ⋮
# 2315 2.408554e-55
# 2316 2.408554e-55
# 2317 2.408554e-55
# 2318 2.408554e-55
# 2319 2.408554e-55
# 2320 2.408554e-55
# 2321 2.408554e-55
# 2322 2.408554e-55
# 2323 2.408554e-55
# 2324 2.408554e-55
# 2325 2.408554e-55
# 2326 2.408554e-55
# 2327 2.408554e-55
# 2328 2.408554e-55
# 2329 2.408554e-55
# 2330 2.408554e-55
# 2331 2.408554e-55
# 2332 2.408554e-55
# 2333 2.408554e-55
# 2334 2.408554e-55
# 2335 2.408554e-55
# 2336 2.408554e-55
# 2337 4.608832e-14
# 2338 4.608832e-14
# 2339 4.608832e-14
# 2340 4.608832e-14
# 2341 4.608832e-14
# 2342 4.608832e-14
# 2343 4.608832e-14
# 2344 4.608832e-14
